# %%
# !pip install -q streamlit #install streamlit - commment out when done

# %%
#!wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip - commment out when done
#!unzip ngrok-stable-linux-amd64.zip - commment out when done

# %%
# !pip install streamlit --upgrade #- commment out when done

# %%
# !pip install prob140 #- commment out when done

# %%
# !pip install datascience #- commment out when done

# %%
# !wget /work/UI/HONDEZVOUS_UI_PREDLOC.py
# Out:
# /work/UI/HONDEZVOUS_UI_PREDLOC.py: Scheme missing.

# %%
get_ipython().system_raw('./ngrok http 8501 &')

# %%
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    'import sys, json; print("Execute the next cell and the go to the following URL: " +json.load(sys.stdin)["tunnels"][0]["public_url"])'
# Out:
# Execute the next cell and the go to the following URL: https://7c694f38594e.ngrok.io

# %%
# !streamlit run HONDEZVOUS_UI_PREDLOC.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.3.205.174:8501
#   External URL: http://52.5.148.98:8501
#
# 34 clusters
# 105 noisey values
# 34 clusters
# 105 noisey values
# ^C
#   Stopping...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=608d4940-9d52-4d53-8e1b-b72eb309e61f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
